# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc('text', usetex=True)
matplotlib.rcParams['text.latex.preamble'] = r"\usepackage{amsmath,amssymb}"
plt.style.use('plots.mplstyle')
import warnings
from py_code import test_model
warnings.filterwarnings('ignore')
from matplotlib.patches import Patch

# %%
train_path = ["dfs_feats/array/train/sm_bkg/100110TeV_030deg_180R170h_13FF_r0R300/df_mPMT_NOADC_1bkg13smu_inf_pe.csv"]
label =["100300TeV_030deg_4FF_180R175h_Black_1bkg13smu_mPMT"]
model_save_path = ["models_ML/HAWCSim_array/100300TeV_030deg_4FF_180R175h_Black/"]
model_save_path = ["models_ML/HAWCSim_array/100300TeV_030deg_4FF_180R175h_Black/"]
output_results_path = ["output_files_ML/HAWCSim_array/test/100300TeV_030deg_4FF_180R175h_Black/"]
test_path = ["dfs_feats/HAWCSim_array/test/100110TeV_030deg_180R170h_4FF_r0R300/df_mPMT_NOADC_1_inf_pe.csv"]

# %%
rc, pr, pr_auc, baseline, y_te, p_te = test_model.test(txt_name = "test_results.txt", path = test_path[0], model_save_path = model_save_path[0] + "model_" + label[0]  + ".joblib", output_results_path = output_results_path[0], plot_pr = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 rc, pr, pr_auc, baseline, y_te, p_te = test_model.test(txt_name = "test_results.txt", path = test_path[0], model_save_path = model_save_path[0] + "model_" + label[0]  + ".joblib", output_results_path = output_results_path[0], plot_pr = False)
#
# File ~/SWGO_Soft/ML_multiPMT/py_code/test_model.py:15, in test(txt_name, path, model_save_path, output_results_path, traces, plot_pr)
#      14 def test(txt_name : str, path: str, model_save_path: str, output_results_path: str, traces = False, plot_pr = True):
# ---> 15     df = pd.read_csv(path)
#      16     if not traces:
#      17         X_te = df.drop(columns=['IsThereMuon', "ch_0", "ch_ref", "ch_60", "ch_120", "ch_180", "ch_240", "ch_300", "ch0"], errors='ignore')
#
# ...

# %%
rc, pr, y_te, p_te  = np.loadtxt("output_files_ML/100110TeV_030deg_180R170h_4FF_r0R300/test_results.txt").T

# %%
bins = 30

x_s, icdf_s = test_model.binned_inv_cdf(p_te[y_te == 1], bins=bins)
x_b, icdf_b = test_model.binned_inv_cdf(p_te[y_te == 0], bins=bins)

u = np.linspace(0, 1, len(icdf_s), endpoint=True)
du = u[1] - u[0]

pdf_s = du / np.diff(icdf_s, append=icdf_s[-1])
pdf_b = du / np.diff(icdf_b, append=icdf_b[-1])

pdf_s = np.clip(pdf_s, 0, np.inf)
pdf_b = np.clip(pdf_b, 0, np.inf)

plt.figure(figsize=(7, 6))

plt.step(u, icdf_s, where="post", lw=1.5, color="red", label=r"stations w/ $\mu^{\pm}$")
plt.step(u, icdf_b, where="post", lw=1.5, color="black", label=r"stations w/out $\mu^{\pm}$")

plt.xlabel("Probability", fontsize = 24)
plt.ylabel("Inverse Cumulative Counts", fontsize = 24)
plt.xticks([0, 0.2, 0.4, 0.6, 0.8, 1], fontsize = 24)
plt.yticks([0, 0.2, 0.4, 0.6, 0.8, 1], fontsize = 24)
plt.xlim(-0.05, 1.05)

plt.legend(frameon=True, fontsize=18, loc=(0.5,0.75), facecolor="white", framealpha=1, edgecolor = "black")
plt.grid(True, alpha=0.2)
plt.tight_layout()
path = "pictures/inverse_cdf/"
plt.savefig(path + "inv_cum_100110TeV_030deg_4FF_r0R300_1bkg13smu.pdf", dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
bins = 30
plt.figure(figsize=(7, 6))

plt.hist(p_te[y_te == 1],bins=bins, density=True,histtype="stepfilled", color="red", alpha=0.1)
plt.hist(p_te[y_te == 1],bins=bins, density=True,histtype="step", color="red", lw=1.5)
plt.hist(p_te[y_te == 0],bins=bins, density=True,histtype="stepfilled", color="black", alpha=0.1)
plt.hist(p_te[y_te == 0],bins=bins, density=True,histtype="step", color="black", lw=1.5)

print("Number of true muons stations = ", len(y_te[y_te == 1]))
print("Number of non-muons stations = ", len(y_te[y_te == 0]))
 
handles = [
    Patch(facecolor=(1,0,0,0.1), edgecolor=(1,0,0,1), linewidth=1, label=r"stations w/ $\mu^{\pm}$"),
    Patch(facecolor=(0,0,0,0.1), edgecolor=(0,0,0,1), linewidth=1, label=r"stations w/out $\mu^{\pm}$"),]

plt.xlabel("Probability", fontsize = 24)
plt.ylabel("Normalized Counts [A.U.]", fontsize = 24)
plt.xticks([0, 0.2, 0.4, 0.6, 0.8, 1], fontsize = 24)
plt.yticks(fontsize = 24)

plt.legend(handles = handles, frameon=True, fontsize=18, facecolor="white", edgecolor = "black", framealpha=1, loc=(0.5,0.75))
plt.grid(True, alpha=0.2)
plt.tight_layout()
path = "pictures/probability_dist/"
plt.savefig(path + "prob_dist_100110TeV_030deg_4FF_r0R300_1bkg13smu.pdf", dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
def load_feat(path):
    fts, vals = [], []
    with open(path) as f:
        for l in f:
            if l.strip():
                n, v = l.strip().split()
                fts.append(n)
                vals.append(float(v))
    return np.array(fts), np.array(vals)


imp_feat, imp_vals = load_feat(feat_imp_save_path[0] + "xgb_feature_importance_" + label[0] + ".txt")


idx = np.argsort(imp_vals)

plt.figure(figsize=(16, 9))

plt.bar(imp_feat[idx], imp_vals[idx], color="black", alpha=0.1)
plt.bar(imp_feat[idx], imp_vals[idx], facecolor='none', edgecolor='black', linewidth=1.5)

plt.ylabel("XGB Gain", fontsize=30)

plt.tick_params(axis='x', which='both', bottom=False, top=False, left=False, right=False)

plt.xticks(rotation = 90, fontsize = 24)
plt.yticks(fontsize = 24)

plt.yscale("log")
plt.gca().invert_xaxis()  

plt.grid(True, axis='y', alpha=0.2)

path = "pictures/features_gain/"
plt.savefig(path + "feat_gain_100110TeV_030deg_4FF_r0R300_1bkg13smu.pdf", dpi=300, bbox_inches='tight')


plt.show()
