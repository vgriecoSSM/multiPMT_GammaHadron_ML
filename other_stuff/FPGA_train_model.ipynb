# %%
import warnings
from py_code import FPGA_XGB_IC_model
warnings.filterwarnings('ignore')

# %%
train_path = ["/home/grieco/SWGO_Soft/ML_multiPMT/dfs_feats/FPGA_ML/sm_bkg/FPGA_df_mPMT_NOADC_13bkg13smu_pe.parquet"]
label =["FPGA_100160TeV_025deg_4FF_180R175h_Black_13petrain_13petest_500ns"]
model_save_path = ["models_ML/FPGA_ML/"]
feat_imp_save_path = ["models_ML/FPGA_ML/"]

# %%
for path, lab in zip(train_path, label):
    print(f"{lab} has {FPGA_XGB_IC_model.get_prauc_baseline(path):.4f} as baseline prauc")
# Out:
# Number of muons events =  16970
# Number of NOT muons events =  99659
# FPGA_100160TeV_025deg_4FF_180R175h_Black_13petrain_13petest_500ns has 0.1455 as baseline prauc

# %%
min_st_dist = 0
max_st_dist = 700
pe_min = 13
FPGA_XGB_IC_model.train(path = train_path[0], feat_imp_save_path = feat_imp_save_path[0] + "xgb_feature_importance_" + label[0] + ".txt" , model_save_path = model_save_path[0] + "model_" + label[0]  + ".joblib", min_st_dist = min_st_dist, max_st_dist = max_st_dist, pe_min = pe_min, plot_imp = False)
# Out:
# ...
#   0%|          | 0/15 [00:00<?, ?it/s]
