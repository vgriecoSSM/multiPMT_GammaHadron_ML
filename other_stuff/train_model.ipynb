# %%
import warnings
from py_code import model_XGBoost_IC
warnings.filterwarnings('ignore')

# %%
train_path = ["dfs_feats/array/train/sm_bkg/100110TeV_030deg_180R170h_13FF_r0R300/df_mPMT_NOADC_1bkg13smu_inf_pe.csv"]
label =["100110TeV_030deg_180R170h_13FF_r0R300_1bkg13smu_mPMT"]
model_save_path = ["models_ML/100110TeV_030deg_180R170h_13FF_r0R300/"]
feat_imp_save_path = ["models_ML/100110TeV_030deg_180R170h_13FF_r0R300/"]

# %%
for path, lab in zip(train_path, label):
    print(f"{lab} has {model_XGBoost_IC.get_prauc_baseline(path):.4f} as baseline prauc")
# Out:
# 100110TeV_030deg_180R170h_13FF_r0R300_1bkg13smu_mPMT has 0.2341 as baseline prauc

# %%
model_XGBoost_IC.train(path = train_path[0], feat_imp_save_path = feat_imp_save_path[0] + "xgb_feature_importance_" + label[0] + ".txt" , model_save_path = model_save_path[0] + "model_" + label[0]  + ".joblib", plot_imp = False)
# Out:
# ...
#   0%|          | 0/30 [00:00<?, ?it/s]
