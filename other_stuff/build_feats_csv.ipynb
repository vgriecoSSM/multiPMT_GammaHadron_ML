# %%
from py_code import build_feats_csv
import numpy as np
import pandas as pd

# %%
build_feats_csv.build_df_feats_NOADC_mPMT(trace_path = "dfs_traces/array/train/sm/100110TeV_030deg_180R170h_13FF_r0R300/Traces_DF_wpefrac.csv", save_path = "dfs_feats/array/train/sm/100110TeV_030deg_180R170h_13FF_r0R300/df_mPMT_NOADC_13_inf_pe.csv", pe_threshold = 13, pe_lim = np.inf, ch0_present = False)
build_feats_csv.build_df_feats_NOADC_mPMT(trace_path = "dfs_traces/array/train/bkg/100110TeV_030deg_180R170h_13FF_r0R300/Traces_DF_wpefrac.csv", save_path = "dfs_feats/array/train/bkg/100110TeV_030deg_180R170h_13FF_r0R300/df_mPMT_NOADC_1_inf_pe.csv", pe_threshold = 1, pe_lim = np.inf, ch0_present = False)
#build_feats_csv.build_df_feats_NOADC_mPMT(trace_path = "dfs_traces/array/test/100110TeV_030deg_180R170h_4FF_r0R300/Traces_DF_wpefrac.csv", save_path = "dfs_feats/array/test/100110TeV_030deg_180R170h_4FF_r0R300/df_mPMT_NOADC_1_inf_pe.csv", mu_frac = 0, pe_threshold = 1, pe_lim = np.inf, ch0_present = False)
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 build_feats_csv.build_df_feats_NOADC_mPMT(trace_path = "dfs_traces/array/train/sm/100110TeV_030deg_180R170h_13FF_r0R300/Traces_DF_wpefrac.csv", save_path = "dfs_feats/array/train/sm/100110TeV_030deg_180R170h_13FF_r0R300/df_mPMT_NOADC_13_inf_pe.csv", pe_threshold = 13, pe_lim = np.inf, ch0_present = False)
#       2 build_feats_csv.build_df_feats_NOADC_mPMT(trace_path = "dfs_traces/array/train/bkg/100110TeV_030deg_180R170h_13FF_r0R300/Traces_DF_wpefrac.csv", save_path = "dfs_feats/array/train/bkg/100110TeV_030deg_180R170h_13FF_r0R300/df_mPMT_NOADC_1_inf_pe.csv", pe_threshold = 1, pe_lim = np.inf, ch0_present = False)
# ...

# %%
df_sm = pd.read_csv("dfs_feats/array/train/sm/100110TeV_030deg_180R170h_13FF_r0R300/df_mPMT_NOADC_13_inf_pe.csv")
df_bkg = pd.read_csv("dfs_feats/array/train/bkg/100110TeV_030deg_180R170h_13FF_r0R300/df_mPMT_NOADC_1_inf_pe.csv")
df_train = pd.concat([df_sm, df_bkg], axis=0)
df_train.to_csv("/home/grieco/SWGO_Soft/ML_multiPMT/dfs_feats/array/train/sm_bkg/100110TeV_030deg_180R170h_13FF_r0R300/df_mPMT_NOADC_1bkg13smu_inf_pe.csv", index = False)
