# %%
import sys
sys.path.append("../")
import warnings
from py_code import XGBoost_IC_test_model
warnings.filterwarnings('ignore')
from pathlib import Path
import glob
import os

# %% [markdown]
# # Apply trained model on test events
#
# This code reads the .joblib file with the trained Machine Learning model and deploys it to previously made feature tables for test events, gammas, protons and SMONLY protons. Creates one .txt file for each event and stores it in the "output" directory.
# A cut on distances and pe number can be selected as well. In the txt all probabilities of the station are saved with their real label (1 for muons, 0 for non muons).
#
# - Specify feature tables directory of the test events
# - Specify save path for txt files
# - Set minimum and maximum distance as well as minimum pe number
# - Specify the function that deploys the model (should be one for each model)
# - **MODEL MUST BE THE SAME FOR ALL TEST EVENTS**

# %%
# Specify model and label as well as feature directory
label = "100160TeV_025deg_4FF_180R175h_Black_13petrain_13petest_500ns"
model_save_dir = "../models_ML/HAWCSim_array/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/"
feat_imp_save_dir = "../models_ML/HAWCSim_array/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/"

# Set desired ranges
min_st_dist = 200
max_st_dist = 700
pe_min = 13

# %%
# Specify read and save directories for test gammas
GAMMAS_feats_test_dir = Path("../dfs_feats/HAWCSim_array/test_gammas/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/")
GAMMAS_probs_save_dir = "../output_files_ML/HAWCSim_array/test_gammas/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/"

# Specify read and save directories for test protons
PROTONS_feats_test_dir = Path("../dfs_feats/HAWCSim_array/test_protons/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/")
PROTONS_probs_save_dir = "../output_files_ML/HAWCSim_array/test_protons/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/"

# Specify read and save directories for test protons SM-ONLY
SMONLY_feats_test_dir = Path("../dfs_feats/HAWCSim_array/test_protons_SMONLY/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/")
SMONLY_probs_save_dir = "../output_files_ML/HAWCSim_array/test_protons_SMONLY/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/"

# %% [markdown]
# # Apply on Gammas

# %%
for f in glob.glob(GAMMAS_probs_save_dir + "*.txt"):
    os.remove(f)

for csv_file in GAMMAS_feats_test_dir.glob("*.parquet"):
    name = csv_file.stem   
    print(f"Processing file: {name}") 
    csv_file_name = str(csv_file)
    feats_path = csv_file_name
    rc, pr, pr_auc, baseline, y_te, p_te = XGBoost_IC_test_model.test(txt_name = name + ".txt",
                                                               path = GAMMAS_feats_test_dir,
                                                               model_save_path = model_save_dir + "model_" + label + ".joblib",
                                                               output_results_path = GAMMAS_probs_save_dir,
                                                               min_st_dist = min_st_dist,
                                                               max_st_dist = max_st_dist,
                                                               pe_min = pe_min,
                                                               plot_pr = False
                                                               )
# Out:
# Processing file: DAT100081_2
# Processing file: DAT100473_4
# Processing file: DAT100061_7
# Processing file: DAT100309_2
# Processing file: DAT100467_2
# Processing file: DAT100101_3
# Processing file: DAT100467_6
# Processing file: DAT100101_7
# Processing file: DAT100098_9
# Processing file: DAT100115_1
# Processing file: DAT100493_5
# Processing file: DAT100115_9
# Processing file: DAT100050_8
# Processing file: DAT100075_9
# Processing file: DAT100411_2
# Processing file: DAT100038_11
# Processing file: DAT100125_2
# Processing file: DAT100114_1
# Processing file: DAT100311_1
# Processing file: DAT100410_6
# Processing file: DAT100305_3
# Processing file: DAT100320_2
# Processing file: DAT100052_4
# Processing file: DAT100063_3
# Processing file: DAT100465_6
# Processing file: DAT100454_5
# Processing file: DAT100491_1
# Processing file: DAT100181_8
# Processing file: DAT100413_2
# Processing file: DAT100306_3
# Processing file: DAT100001_1
# Processing file: DAT100175_3
# ...

# %% [markdown]
# # Apply on Protons

# %%
for f in glob.glob(PROTONS_probs_save_dir + "*.txt"):
    os.remove(f)

for csv_file in PROTONS_feats_test_dir.glob("*.parquet"):
    name = csv_file.stem   
    print(f"Processing file: {name}") 
    csv_file_name = str(csv_file)
    feats_path = csv_file_name
    rc, pr, pr_auc, baseline, y_te, p_te = XGBoost_IC_test_model.test(txt_name = name + ".txt",
                                                               path = PROTONS_feats_test_dir,
                                                               model_save_path = model_save_dir + "model_" + label + ".joblib",
                                                               output_results_path = PROTONS_probs_save_dir,
                                                               min_st_dist = min_st_dist,
                                                               max_st_dist = max_st_dist,
                                                               pe_min = pe_min,
                                                               plot_pr = False
                                                               )

# %% [markdown]
# # Apply on Protons SMONLY

# %%
for f in glob.glob(SMONLY_probs_save_dir + "*.txt"):
    os.remove(f)

for csv_file in SMONLY_feats_test_dir.glob("*.parquet"):
    name = csv_file.stem   
    print(f"Processing file: {name}") 
    csv_file_name = str(csv_file)
    feats_path = csv_file_name
    rc, pr, pr_auc, baseline, y_te, p_te = XGBoost_IC_test_model.test(txt_name = name + ".txt",
                                                               path = SMONLY_feats_test_dir,
                                                               model_save_path = model_save_dir + "model_" + label + ".joblib",
                                                               output_results_path = SMONLY_probs_save_dir,
                                                               min_st_dist = min_st_dist,
                                                               max_st_dist = max_st_dist,
                                                               pe_min = pe_min,
                                                               plot_pr = False
                                                               )
# Out:
# Processing file: DAT1405058_12
# Processing file: DAT1405022_3
# Processing file: DAT1405098_22
# Processing file: DAT1405036_5
# Processing file: DAT1405025_13
# Processing file: DAT1400204_15
# Processing file: DAT1405065_8
# Processing file: DAT1405074_12
# Processing file: DAT1405091_3
# Processing file: DAT1405011_16
# Processing file: DAT1405013_8
# Processing file: DAT1405085_5
# Processing file: DAT1405092_12
# Processing file: DAT1405091_7
# Processing file: DAT1405037_5
# Processing file: DAT1405028_15
# Processing file: DAT1405026_10
# Processing file: DAT1405077_19
# Processing file: DAT1400204_2
# Processing file: DAT1405058_6
# Processing file: DAT1405089_18
# Processing file: DAT1405065_24
# Processing file: DAT1405069_1
# Processing file: DAT1400103_4
# Processing file: DAT1405049_28
# Processing file: DAT1405043_10
# Processing file: DAT1405006_6
# Processing file: DAT1405016_24
# Processing file: DAT1405041_9
# Processing file: DAT1405055_7
# ...
