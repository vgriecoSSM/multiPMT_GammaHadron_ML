# %%
import sys
sys.path.append("../")
from py_code import build_feats_csv
import numpy as np
import pandas as pd
from pathlib import Path
import glob
import os
import gc

# %% [markdown]
# # Build features tables from traces files for training and test
#
# In the following snippets features are built out of extracted traces event by event. Said feature tables are meant for training and testing ML models. Different parquet builder are available in py_code/build_csv.py depending on ADC availability and characteristics. This is done four times respectively for : training on protons, testing on protons, testing on gammas, testing on single muon stations in proton showers.
#
# - Specify saving paths for the parquet of the features.
# - Specify minimum number of photoelectrons (pe) for a station to be considered.
# - Select maximum time window.
# - Select features-builder function from builder_csv.py.
# - **Create all required directories if they are not already present. Label each directory clearly and unambiguously, using descriptive names that reflect its purpose and contents.**
# - **Make sure that pe cuts are the same for single muons and background.**
# - **Make sure all other parameters are set to the same value to avoid dataset mismatches.**
# - **Use same builder functions for all dataset**

# %%
# Specify input and save paths for training traces and training features
TRAIN_traces_input_path_smu = Path("../dfs_traces/HAWCSim_array/train/sm/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/")
TRAIN_traces_input_path_nmu = Path("../dfs_traces/HAWCSim_array/train/bkg/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/")

TRAIN_features_save_path_smu = "../dfs_feats/HAWCSim_array/train/sm/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/"
TRAIN_features_save_path_nmu = "../dfs_feats/HAWCSim_array/train/bkg/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/"

TRAIN_features_save_path_smu_bkg = "../dfs_feats/HAWCSim_array/train/sm_bkg/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/df_mPMT_NOADC_13bkg13smu_pe.parquet"


# Specify input and save paths for test proton traces and test proton features
TEST_PROTONS_traces_input_path = Path("../dfs_traces/HAWCSim_array/test_protons/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/")
TEST_PROTONS_features_save_path = "../dfs_feats/HAWCSim_array/test_protons/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/"

# Specify input and save paths for test gamma traces and test gamma features
TEST_GAMMAS_traces_input_path = Path("../dfs_traces/HAWCSim_array/test_gammas/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/")
TEST_GAMMAS_features_save_path = "../dfs_feats/HAWCSim_array/test_gammas/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/"

# Specify input and save paths for test proton sm-only traces and test proton sm-only features
TEST_PROTONS_SMONLY_traces_input_path = Path("../dfs_traces/HAWCSim_array/test_protons/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/")
TEST_PROTONS_SMONLY_features_save_path = "../dfs_feats/HAWCSim_array/test_protons_SMONLY/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/"

# Set pe threshold and time window
pe_min = 13  # minimum pe number
max_time = 500   # maximum time window

# %% [markdown]
# # TRAIN FEATURES (Protons)

# %%
for f in glob.glob(TRAIN_features_save_path_smu + "*.parquet"):        # Clean directory 
    os.remove(f)

for f in glob.glob(TRAIN_features_save_path_nmu + "*.parquet"):        # Clean directory
    os.remove(f)

for parquet_file in TRAIN_traces_input_path_smu.glob("*.parquet"):

    name = parquet_file.stem   
    print(f"Processing file: {name}") 
    parquet_file_name = str(parquet_file)
    trace_path = parquet_file_name
    
    build_feats_csv.build_df_feats_NOADC_mPMT(trace_path = trace_path, 
                                              save_path = TRAIN_features_save_path_smu + name + ".parquet",
                                              mu_frac = 0,              # Get events with pe fraction of muons above 0 (all muon events)
                                              pe_threshold = pe_min, # Set pe cut
                                              pe_lim = np.inf,          # Set pe limit
                                              ch0_present = False,      # Include central channel
                                              max_time = max_time       # Set max time window
                                              )
    gc.collect()

gc.collect()
print("All done! :))")

for parquet_file in TRAIN_traces_input_path_nmu.glob("*.parquet"):
    
    name = parquet_file.stem   
    print(f"Processing file: {name}") 
    parquet_file_name = str(parquet_file)
    trace_path = parquet_file_name
    
    build_feats_csv.build_df_feats_NOADC_mPMT(trace_path = trace_path, 
                                              save_path = TRAIN_features_save_path_nmu + name + ".parquet",
                                              mu_frac = 0,
                                              pe_threshold = pe_min,
                                              pe_lim = np.inf,
                                              ch0_present = False,
                                              max_time = max_time
                                              )
    gc.collect()
    
print("All done! :))")

gc.collect()
feats_path_smu = Path(TRAIN_features_save_path_smu)
feats_path_nmu = Path(TRAIN_features_save_path_nmu)

feats_files = list(feats_path_smu.glob("*.parquet")) + list(feats_path_nmu.glob("*.parquet"))

dfs = [pd.read_parquet(f) for f in feats_files]
combined_df = pd.concat(dfs, ignore_index = True)

combined_df.to_parquet(TRAIN_features_save_path_smu_bkg)
gc.collect()
# Out:
# Processing file: DAT1400038_25
# Processing file: DAT1400032_11
# Processing file: DAT1400037_9
# Processing file: DAT1400081_21
# Processing file: DAT1400036_5
# Processing file: DAT1400036_1
# Processing file: DAT1400071_6
# Processing file: DAT1400036_9
# Processing file: DAT1400035_1
# Processing file: DAT1400012_23
# Processing file: DAT1400043_9
# Processing file: DAT1400038_8
# Processing file: DAT1400035_5
# Processing file: DAT1400021_3
# Processing file: DAT1400092_3
# Processing file: DAT1400095_16
# Processing file: DAT1400037_10
# Processing file: DAT1400020_7
# Processing file: DAT1400087_9
# Processing file: DAT1400033_13
# Processing file: DAT1400095_20
# Processing file: DAT1400075_2
# Processing file: DAT1400012_19
# Processing file: DAT1400043_10
# Processing file: DAT1400012_11
# Processing file: DAT1400032_5
# Processing file: DAT1400087_11
# Processing file: DAT1400014_8
# Processing file: DAT1400035_19
# Processing file: DAT1400031_9
# Processing file: DAT1400076_21
# Processing file: DAT1400094_18
# Processing file: DAT1400030_9
# Processing file: DAT1400071_13
# Processing file: DAT1400014_13
# Processing file: DAT1400099_16
# Processing file: DAT1400081_17
# Processing file: DAT1400010_26
# Processing file: DAT1400030_1
# Processing file: DAT1400036_16
# Processing file: DAT1400099_3
# Processing file: DAT1400030_15
# Processing file: DAT1400087_18
# Processing file: DAT1400081_4
# Processing file: DAT1400030_11
# Processing file: DAT1400043_11
# Processing file: DAT1400095_2
# Processing file: DAT1400031_4
# Processing file: DAT1400035_10
# Processing file: DAT1400094_11
# Processing file: DAT1400076_7
# Processing file: DAT1400020_17
# Processing file: DAT1400020_13
# Processing file: DAT1400030_8
# Processing file: DAT1400038_24
# Processing file: DAT1400038_20
# Processing file: DAT1400012_1
# Processing file: DAT1400013_9
# Processing file: DAT1400013_12
# Processing file: DAT1400076_16
# Processing file: DAT1400092_6
# Processing file: DAT1400038_1
# Processing file: DAT1400092_2
# Processing file: DAT1400021_6
# Processing file: DAT1400021_2
# Processing file: DAT1400021_15
# Processing file: DAT1400037_15
# Processing file: DAT1400095_8
# Processing file: DAT1400075_1
# Processing file: DAT1400095_4
# Processing file: DAT1400030_13
# Processing file: DAT1400033_2
# Processing file: DAT1400099_1
# Processing file: DAT1400094_8
# Processing file: DAT1400021_21
# Processing file: DAT1400033_6
# Processing file: DAT1400013_12
# Processing file: DAT1400012_6
# Processing file: DAT1400076_16
# Processing file: DAT1400038_20
# Processing file: DAT1400013_6
# Processing file: DAT1400071_8
# Processing file: DAT1400038_24
# Processing file: DAT1400036_7
# Processing file: DAT1400021_9
# Processing file: DAT1400092_5
# Processing file: DAT1400043_7
# Processing file: DAT1400038_6
# Processing file: DAT1400037_15
# Processing file: DAT1400021_15
# Processing file: DAT1400092_9
# Processing file: DAT1400021_5
# Processing file: DAT1400020_5
# Processing file: DAT1400021_21
# Processing file: DAT1400032_5
# Processing file: DAT1400033_14
# Processing file: DAT1400075_2
# Processing file: DAT1400030_13
# Processing file: DAT1400076_22
# Processing file: DAT1400030_1
# Processing file: DAT1400030_9
# Processing file: DAT1400020_11
# Processing file: DAT1400014_10
# Processing file: DAT1400038_18
# Processing file: DAT1400031_9
# Processing file: DAT1400014_8
# Processing file: DAT1400014_14
# Processing file: DAT1400071_10
# Processing file: DAT1400020_19
# Processing file: DAT1400036_9
# Processing file: DAT1400071_6
# Processing file: DAT1400036_1
# Processing file: DAT1400010_13
# Processing file: DAT1400020_23
# Processing file: DAT1400010_17
# Processing file: DAT1400036_5
# Processing file: DAT1400037_9
# Processing file: DAT1400076_10
# Processing file: DAT1400035_20
# Processing file: DAT1400095_11
# Processing file: DAT1400095_19
# Processing file: DAT1400087_9
# Processing file: DAT1400087_24
# Processing file: DAT1400020_7
# Processing file: DAT1400092_3
# Processing file: DAT1400021_3
# Processing file: DAT1400035_5
# Processing file: DAT1400038_8
# Processing file: DAT1400043_9
# Processing file: DAT1400035_1
# Processing file: DAT1400038_23
# Processing file: DAT1400071_23
# Processing file: DAT1400013_9
# Processing file: DAT1400012_1
# Processing file: DAT1400035_21
# Processing file: DAT1400076_15
# Processing file: DAT1400091_25
# Processing file: DAT1400095_10
# Processing file: DAT1400021_2
# Processing file: DAT1400021_12
# Processing file: DAT1400021_6
# Processing file: DAT1400092_2
# Processing file: DAT1400038_1
# Processing file: DAT1400092_6
# Processing file: DAT1400095_2
# Processing file: DAT1400081_4
# Processing file: DAT1400021_20
# Processing file: DAT1400030_12
# Processing file: DAT1400012_17
# Processing file: DAT1400091_17
# Processing file: DAT1400099_3
# Processing file: DAT1400094_16
# Processing file: DAT1400094_12
# Processing file: DAT1400030_8
# Processing file: DAT1400076_23
# Processing file: DAT1400076_7
# Processing file: DAT1400081_11
# Processing file: DAT1400031_4
# All done! :))
# 0

# %% [markdown]
# # TEST PROTON FEATURES

# %%
for f in glob.glob(TEST_PROTONS_features_save_path + "*.parquet"):
    os.remove(f)

for parquet_file in TEST_PROTONS_traces_input_path.glob("*.parquet"):
    
    name = parquet_file.stem   
    print(f"Processing file: {name}") 
    parquet_file_name = str(parquet_file)
    trace_path = parquet_file_name
    
    build_feats_csv.build_df_feats_NOADC_mPMT(trace_path = trace_path,
                                              save_path = TEST_PROTONS_features_save_path + name + ".parquet",
                                              mu_frac = 0,
                                              pe_threshold = pe_min,
                                              pe_lim = np.inf,
                                              ch0_present = False,
                                              max_time = max_time)
    gc.collect()
    
gc.collect()
# Out:
# Processing file: DAT1405062_8
# Processing file: DAT1405034_23
# Processing file: DAT1405019_9
# Processing file: DAT1400211_18
# Processing file: DAT1405012_17
# Processing file: DAT1400105_4
# Processing file: DAT1405052_14
# Processing file: DAT1400200_12
# Processing file: DAT1405055_9
# Processing file: DAT1405039_15
# Processing file: DAT1400210_6
# Processing file: DAT1405037_10
# Processing file: DAT1405023_1
# Processing file: DAT1400235_7
# Processing file: DAT1400228_23
# Processing file: DAT1400106_14
# Processing file: DAT1405098_18
# Processing file: DAT1405090_9
# Processing file: DAT1405044_14
# Processing file: DAT1400216_12
# Processing file: DAT1405092_20
# Processing file: DAT1400235_3
# Processing file: DAT1405021_10
# Processing file: DAT1400108_11
# Processing file: DAT1400210_2
# Processing file: DAT1405009_21
# Processing file: DAT1405039_11
# Processing file: DAT1405037_14
# Processing file: DAT1400209_5
# Processing file: DAT1400238_2
# Processing file: DAT1405064_2
# Processing file: DAT1405058_20
# Processing file: DAT1405068_10
# Processing file: DAT1405039_19
# Processing file: DAT1405149_16
# Processing file: DAT1405055_1
# Processing file: DAT1405084_3
# Processing file: DAT1400222_13
# Processing file: DAT1405040_25
# Processing file: DAT1405044_18
# Processing file: DAT1400234_7
# Processing file: DAT1400208_9
# Processing file: DAT1400215_11
# Processing file: DAT1405091_23
# Processing file: DAT1405047_17
# Processing file: DAT1405012_23
# Processing file: DAT1400203_15
# Processing file: DAT1405051_13
# Processing file: DAT1405061_23
# Processing file: DAT1405013_6
# Processing file: DAT1400233_21
# Processing file: DAT1400220_5
# Processing file: DAT1400211_2
# Processing file: DAT1405068_3
# Processing file: DAT1400105_13
# Processing file: DAT1405049_16
# Processing file: DAT1400207_24
# Processing file: DAT1405083_16
# Processing file: DAT1405065_2
# Processing file: DAT1405091_1
# Processing file: DAT1400211_20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 11
#       8     parquet_file_name = str(parquet_file)
#       9     trace_path = parquet_file_name
# ---> 11     build_feats_csv.build_df_feats_NOADC_mPMT(trace_path = trace_path,
#      12                                               save_path = TEST_PROTONS_features_save_path + name + ".parquet",
#      13                                               mu_frac = 0,
#      14                                               pe_threshold = pe_min,
#      15                                               pe_lim = np.inf,
#      16                                               ch0_present = False,
#      17                                               max_time = max_time)
#      18     gc.collect()
#      20 gc.collect()
#
# File ~/SWGO_Soft/tmp_ML_multiPMT/gamma_hadron_discrimination/../py_code/build_feats_csv.py:12, in build_df_feats_NOADC_mPMT(trace_path, save_path, mu_frac, pe_threshold, pe_lim, ch0_present, max_time)
#       9 def build_df_feats_NOADC_mPMT(trace_path : str, save_path : str, mu_frac : float = 0, pe_threshold = 1, pe_lim = np.inf, ch0_present = False, max_time : int = 100):
#      11     ADC_MHz = None
# ---> 12     df = initialize_df.get_df(path = trace_path, base = "pe", ADC_MHz = ADC_MHz, pe_threshold = pe_threshold, pe_lim = pe_lim)
#      13     df = add_variables.add_time_Asimmetry_2ch(df = df, ch0_present = ch0_present)
#      14     #df = add_variables.add_time_prompt_3ch(df = df, ch0_present = ch0_present)
#
# File ~/SWGO_Soft/tmp_ML_multiPMT/gamma_hadron_discrimination/../py_code/initialize_df.py:154, in get_df(path, base, ADC_MHz, pe_threshold, pe_lim)
#     152 df_ord_with_times = add_variables.add_mult_variables_to_df(df_ord, get_variables.get_first_time)
#     153 df_ord_with_rel_times = add_variables.add_rel_time(df_ord_with_times)
# --> 154 df_with_mult = add_variables.add_multiplicity(df_ord_with_rel_times, pe_trigger = 2, time_frame = 10)
#     155 df = get_ADC_traces.get_ADC_sampled_df(df_with_mult, ADC_MHz = ADC_MHz)
#     156 df = add_variables.add_single_variable_to_df(df = df, get_var = get_variables.get_total_pe)
#
# File ~/SWGO_Soft/tmp_ML_multiPMT/gamma_hadron_discrimination/../py_code/add_variables.py:108, in add_multiplicity(df, pe_trigger, time_frame)
#     106 for i in range(df.shape[0]):
#     107     channels = [ch0.iloc[i], chref.iloc[i], ch60.iloc[i], ch120.iloc[i], ch180.iloc[i], ch240.iloc[i], ch300.iloc[i]]
# --> 108     multiplicity_val = get_variables.get_multiplicity(channels, pe_trigger, time_frame)
#     109     multiplicity.append(multiplicity_val)
#     110 df["multiplicity"] = multiplicity
#
# File ~/SWGO_Soft/tmp_ML_multiPMT/gamma_hadron_discrimination/../py_code/get_variables.py:198, in get_multiplicity(channels, pe_trigger, time_frame)
#     197 def get_multiplicity(channels : list, pe_trigger = 2, time_frame = 10):
# --> 198     times = get_first_time(channels, pe_thresh = pe_trigger)
#     199     if np.any(~np.isnan(times)):
#     200         first_trigger_time = np.nanmin(times)
#
# File ~/SWGO_Soft/tmp_ML_multiPMT/gamma_hadron_discrimination/../py_code/get_variables.py:54, in get_first_time(channels, pe_thresh)
#      52 for indx, pe in enumerate(ch):
#      53     val += pe
# ---> 54     if val>= pe_thresh:
#      55         times[ch_indx] = indx
#      56         break
#
# KeyboardInterrupt:

# %% [markdown]
# # TEST GAMMAS FEATURES

# %%
for f in glob.glob(TEST_GAMMAS_features_save_path + "*.parquet"):
    os.remove(f)

for parquet_file in TEST_GAMMAS_traces_input_path.glob("*.parquet"):
    
    name = parquet_file.stem   
    print(f"Processing file: {name}") 
    parquet_file_name = str(parquet_file)
    trace_path = parquet_file_name
    
    build_feats_csv.build_df_feats_NOADC_mPMT(trace_path = trace_path,
                                              save_path = TEST_GAMMAS_features_save_path + name + ".parquet",
                                              mu_frac = 0,
                                              pe_threshold = pe_min,
                                              pe_lim = np.inf,
                                              ch0_present = False,
                                              max_time = max_time
                                              )
    gc.collect()

gc.collect()

# %% [markdown]
# # TEST PROTONS SM-ONLY FEATURES

# %%
for f in glob.glob(TEST_PROTONS_SMONLY_features_save_path + "*.parquet"):
    os.remove(f)

for parquet_file in TEST_PROTONS_SMONLY_traces_input_path.glob("*.parquet"):
    
    name = parquet_file.stem   
    print(f"Processing file: {name}") 
    parquet_file_name = str(parquet_file)
    trace_path = parquet_file_name
   
    build_feats_csv.build_df_feats_NOADC_mPMT(trace_path = trace_path,
                                            save_path = TEST_PROTONS_SMONLY_features_save_path + name + ".parquet",
                                            mu_frac = 1,
                                            pe_threshold = pe_min,
                                            pe_lim = np.inf,
                                            ch0_present = False,
                                            max_time = max_time
                                            )
    gc.collect()

gc.collect()
