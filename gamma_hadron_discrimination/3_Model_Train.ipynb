# %%
import sys
sys.path.append("../")
import warnings
from py_code.models import XGBoost_IC_train_model
warnings.filterwarnings('ignore')

# %% [markdown]
# # Train the machine learning model
#
# The pipeline for the model is in the py_code directory and indicated as model + the actual name of the model. The code below sets the minimum and maximum distance of the stations on which to train the model on as well as a cut on the number of photoelectrons.
# The model is stored in a directory containing all .joblil files and the plot importances values, to be called later on. A snippet of code is used to show number of instances for each class and their relative ratio (baseline for PRAUC).
#
# - Specify features tables directory for non-muons + single muons combined dataframe (usually in dfs_feats/...).
# - Specify label for the model. **Be specific!**
# - Specify model and feature importances save directory (should be the same!).
# - Set minimum and maximum distances for the stations and minimum pe number per station.

# %%
train_path = ["../dfs_feats/HAWCSim_array/train/sm_bkg/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/df_mPMT_NOADC_13bkg13smu_pe.parquet"]
label =["100160TeV_025deg_4FF_180R175h_Black_13petrain_13petest_500ns"]
model_save_path = ["../models_ML/HAWCSim_array/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/"]
feat_imp_save_path = ["../models_ML/HAWCSim_array/100160TeV_025deg_4FF_180R175h_Black/13petrain_13petest_500ns/"]

# %%
for path, lab in zip(train_path, label):
    print(f"{lab} has {XGBoost_IC_train_model.get_prauc_baseline(path):.4f} as baseline prauc")
# Out:
# Number of muons events =  4804
# Number of NOT muons events =  28230
# 100160TeV_025deg_4FF_180R175h_Black_13petrain_13petest_500ns has 0.1454 as baseline prauc

# %%
min_st_dist = 0
max_st_dist = 700
pe_min = 13
XGBoost_IC_train_model.train(path = train_path[0], feat_imp_save_path = feat_imp_save_path[0] + "xgb_feature_importance_" + label[0] + ".txt" , model_save_path = model_save_path[0] + "model_" + label[0]  + ".joblib", min_st_dist = min_st_dist, max_st_dist = max_st_dist, pe_min = pe_min, plot_imp = False)
# Out:
# ...
#   0%|          | 0/15 [00:00<?, ?it/s]
